# %% [markdown]
# ## C S 363D HW 10
#
# # Hierarchical Clustering and Cluster Evaluation
#
# ## Ana Williams and Fronrich Puno

# %%
import pandas as pd
import numpy as np
import urllib, json, requests, re
import xlsxwriter

# %% [markdown]
# # Set Up Data

# %%
df = pd.read_excel('blanton_list.xlsx', 
                   dtype={i:object for i in range(0,10)})
df = df[df['Accession #'] != 2016.207]

# %% [markdown]
# ## Fixing duplicates

# %%
#manual fixes
#2016.1 fix
df.at[292,'Accession #'] = '2016.100'
df.at[332,'Accession #'] = '2016.10'
df.at[829,'Accession #'] = '2016.1'
#2014.1 fixes 
df.at[688,'Accession #'] = '2014.100'
df.at[803,'Accession #'] = '2014.1'
#1999.1 fixes
df.at[673,'Accession #'] = '1999.100'
df.at[1165,'Accession #'] = '1999.10'
#2017.14 fixes 
df.at[462,'Accession #'] = '2017.140'
df.at[984,'Accession #'] = '2017.1400'
#2002.900 fixes 
df.at[900,'Accession #'] = '2002.9'
df.at[901,'Accession #'] = '2002.10'
df.at[904,'Accession #'] = '2002.90'
#2019.3 fixes
df.at[428,'Accession #'] = '2019.3'
df.at[841,'Accession #'] = '2019.30'
#2015.300 fixes 
df.at[316,'Accession #'] = '2015.30'
df.at[317,'Accession #'] = '2015.3'
#2016.150 fixes 
df.at[345,'Accession #'] = '2016.15'
df.at[806,'Accession #'] = '2016.150'
#2017.106 fixes 
df.at[450,'Accession #'] = '2017.106'
df.at[1042,'Accession #'] = '2017.1060'
#2016.4 fixes 
df.at[325,'Accession #'] = '2016.4'
df.at[354,'Accession #'] = '2016.40'
#2016.5 fixes
df.at[326,'Accession #'] = '2016.5'
df.at[826,'Accession #'] = '2016.50'
#2016.9 fixes
df.at[281,'Accession #'] = '2016.90'
df.at[331,'Accession #'] = '2016.9'
#2018.15 fixes 
df.at[391,'Accession #'] = '2018.150'
df.at[429,'Accession #'] = '2018.15'
#2017.3 fixes 
df.at[277,'Accession #'] = '2017.30'
df.at[807,'Accession #'] = '2017.3'
#other fixes
df.at[398,''] = '2018.160'
#Title fixes
df.at[879,'Title'] = '"' + 'And He Smote Job with sore Boils...,' + '"' + ' plate 6 from the Illustrations of the Book of Job'
df.at[878,'Title'] = '"' + 'I have heard thee with the hearing of the Ear but now my Eye seeth thee,' + '"' + ' plate 17 from the Illustrations of The Book of Job'

# %%
#Used to see what was doubled and needing fixing 
# df_fix = df['Accession #'].value_counts() 
# df_fix = df_fix[df_fix > 1]
# df_fix

# %%
#Grabbed values needing to be fixed
# df_temp = df[df['Accession #'] == 'G1966.2.154']
# df_temp

# %%
#Saving fixed values to document 
writer = pd.ExcelWriter('blanton_list_fixed.xlsx', engine='xlsxwriter', 
                        options = {'string_to_numbers' : False})
df.to_excel(writer)

writer.save()

# %% [markdown]
# ## Part 2 Find which ones have images

# %%
for row, data in df.iterrows():
    if row == 1372:
        break
    #create url
    title = df.iloc[row]['Title']
    name = df.iloc[row]['Artist sort name']
    accession = df.iloc[row]['Accession #']
        
    url = f"https://collection.blantonmuseum.org/objects-1/info?query=mfs all \"{accession} {title} {name}\"&sort=9"
    #get JSON data and get rid of any trailing 
    response  = requests.get(url)
    text = response.text

    current_has_image = text.find("This object does not have an image") == -1
    
    df.at[row,'has_image'] = False
    if current_has_image:
        print("image found at row " + str(row) + "!")
        df.at[row, 'has_image'] = True
    else:
        print(row)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# image found at row 7!
# image found at row 8!
# image found at row 9!
# image found at row 10!
# image found at row 11!
# image found at row 12!
# image found at row 13!
# image found at row 14!
# image found at row 15!
# image found at row 16!
# image found at row 17!
# image found at row 18!
# image found at row 19!
# image found at row 20!
# image found at row 21!
# image found at row 22!
# image found at row 23!
# image found at row 24!
# image found at row 25!
# image found at row 26!
# image found at row 27!
# image found at row 28!
# image found at row 29!
# image found at row 30!
# image found at row 31!
# image found at row 32!
# image found at row 33!
# image found at row 34!
# image found at row 35!
# image found at row 36!
# image found at row 37!
# 38
# image found at row 39!
# image found at row 40!
# image found at row 41!
# image found at row 42!
# image found at row 43!
# image found at row 44!
# image found at row 45!
# image found at row 46!
# image found at row 47!
# image found at row 48!
# image found at row 49!
# image found at row 50!
# image found at row 51!
# image found at row 52!
# image found at row 53!
# image found at row 54!
# image found at row 55!
# image found at row 56!
# image found at row 57!
# image found at row 58!
# image found at row 59!
# image found at row 60!
# image found at row 61!
# image found at row 62!
# 63
# image found at row 64!
# image found at row 65!
# image found at row 66!
# image found at row 67!
# image found at row 68!
# image found at row 69!
# image found at row 70!
# image found at row 71!
# image found at row 72!
# image found at row 73!
# image found at row 74!
# 75
# image found at row 76!
# image found at row 77!
# image found at row 78!
# 79
# image found at row 80!
# image found at row 81!
# image found at row 82!
# image found at row 83!
# image found at row 84!
# image found at row 85!
# image found at row 86!
# image found at row 87!
# image found at row 88!
# image found at row 89!
# image found at row 90!
# image found at row 91!
# image found at row 92!
# image found at row 93!
# image found at row 94!
# image found at row 95!
# image found at row 96!
# image found at row 97!
# image found at row 98!
# image found at row 99!
# image found at row 100!
# image found at row 101!
# image found at row 102!
# image found at row 103!
# image found at row 104!
# image found at row 105!
# image found at row 106!
# image found at row 107!
# image found at row 108!
# image found at row 109!
# image found at row 110!
# image found at row 111!
# 112
# image found at row 113!
# 114
# image found at row 115!
# image found at row 116!
# image found at row 117!
# image found at row 118!
# image found at row 119!
# image found at row 120!
# image found at row 121!
# image found at row 122!
# image found at row 123!
# image found at row 124!
# image found at row 125!
# image found at row 126!
# image found at row 127!
# image found at row 128!
# image found at row 129!
# image found at row 130!
# image found at row 131!
# image found at row 132!
# 133
# image found at row 134!
# image found at row 135!
# image found at row 136!
# image found at row 137!
# 138
# image found at row 139!
# image found at row 140!
# image found at row 141!
# image found at row 142!
# image found at row 143!
# image found at row 144!
# image found at row 145!
# image found at row 146!
# image found at row 147!
# image found at row 148!
# image found at row 149!
# image found at row 150!
# image found at row 151!
# image found at row 152!
# image found at row 153!
# image found at row 154!
# image found at row 155!
# image found at row 156!
# image found at row 157!
# image found at row 158!
# image found at row 159!
# image found at row 160!
# image found at row 161!
# image found at row 162!
# image found at row 163!
# image found at row 164!
# image found at row 165!
# image found at row 166!
# image found at row 167!
# image found at row 168!
# 169
# 170
# image found at row 171!
# image found at row 172!
# image found at row 173!
# image found at row 174!
# image found at row 175!
# image found at row 176!
# image found at row 177!
# 178
# image found at row 179!
# image found at row 180!
# image found at row 181!
# image found at row 182!
# image found at row 183!
# image found at row 184!
# image found at row 185!
# image found at row 186!
# image found at row 187!
# image found at row 188!
# image found at row 189!
# image found at row 190!
# image found at row 191!
# image found at row 192!
# image found at row 193!
# image found at row 194!
# image found at row 195!
# image found at row 196!
# image found at row 197!
# image found at row 198!
# image found at row 199!
# image found at row 200!
# image found at row 201!
# image found at row 202!
# image found at row 203!
# image found at row 204!
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# image found at row 225!
# image found at row 226!
# image found at row 227!
# image found at row 228!
# image found at row 229!
# image found at row 230!
# image found at row 231!
# image found at row 232!
# image found at row 233!
# image found at row 234!
# image found at row 235!
# image found at row 236!
# image found at row 237!
# image found at row 238!
# image found at row 239!
# image found at row 240!
# image found at row 241!
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# image found at row 260!
# image found at row 261!
# image found at row 262!
# 263
# 264
# 265
# 266
# image found at row 267!
# image found at row 268!
# 269
# image found at row 270!
# image found at row 271!
# image found at row 272!
# image found at row 273!
# image found at row 274!
# image found at row 275!
# image found at row 276!
# image found at row 277!
# image found at row 278!
# 279
# 280
# 281
# image found at row 282!
# image found at row 283!
# image found at row 284!
# 285
# 286
# image found at row 287!
# image found at row 288!
# image found at row 289!
# image found at row 290!
# 291
# 292
# image found at row 293!
# image found at row 294!
# image found at row 295!
# image found at row 296!
# 297
# image found at row 298!
# 299
# image found at row 300!
# 301
# 302
# 303
# image found at row 304!
# image found at row 305!
# 306
# 307
# 308
# image found at row 309!
# image found at row 310!
# image found at row 311!
# image found at row 312!
# image found at row 313!
# image found at row 314!
# image found at row 315!
# image found at row 316!
# image found at row 317!
# 318
# image found at row 319!
# image found at row 320!
# image found at row 321!
# image found at row 322!
# 323
# 324
# 325
# 326
# 327
# image found at row 328!
# 329
# 330
# 331
# image found at row 332!
# 333
# image found at row 334!
# 335
# 336
# image found at row 337!
# image found at row 338!
# image found at row 339!
# 340
# image found at row 341!
# image found at row 342!
# image found at row 343!
# 344
# image found at row 345!
# image found at row 346!
# image found at row 347!
# image found at row 348!
# image found at row 349!
# image found at row 350!
# image found at row 351!
# image found at row 352!
# 353
# image found at row 354!
# image found at row 355!
# image found at row 356!
# image found at row 357!
# image found at row 358!
# 360
# image found at row 361!
# image found at row 362!
# image found at row 363!
# image found at row 364!
# image found at row 365!
# image found at row 366!
# image found at row 367!
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# image found at row 398!
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# image found at row 423!
# image found at row 424!
# image found at row 425!
# image found at row 426!
# image found at row 427!
# 428
# image found at row 429!
# image found at row 430!
# image found at row 431!
# image found at row 432!
# image found at row 433!
# 434
# image found at row 435!
# 436
# 437
# image found at row 438!
# image found at row 439!
# image found at row 440!
# 441
# image found at row 442!
# image found at row 443!
# image found at row 444!
# image found at row 445!
# image found at row 446!
# image found at row 447!
# image found at row 448!
# image found at row 449!
# image found at row 450!
# image found at row 451!
# image found at row 452!
# image found at row 453!
# image found at row 454!
# image found at row 455!
# image found at row 456!
# image found at row 457!
# image found at row 458!
# 459
# 460
# 461
# 462
# 463
# image found at row 464!
# 465
# 466
# 467
# image found at row 468!
# image found at row 469!
# image found at row 470!
# image found at row 471!
# image found at row 472!
# image found at row 473!
# 474
# image found at row 475!
# image found at row 476!
# image found at row 477!
# image found at row 478!
# image found at row 479!
# image found at row 480!
# image found at row 481!
# image found at row 482!
# image found at row 483!
# image found at row 484!
# image found at row 485!
# image found at row 486!
# image found at row 487!
# image found at row 488!
# image found at row 489!
# image found at row 490!
# image found at row 491!
# image found at row 492!
# image found at row 493!
# image found at row 494!
# image found at row 495!
# image found at row 496!
# image found at row 497!
# image found at row 498!
# image found at row 499!
# image found at row 500!
# image found at row 501!
# image found at row 502!
# image found at row 503!
# image found at row 504!
# image found at row 505!
# image found at row 506!
# image found at row 507!
# image found at row 508!
# image found at row 509!
# image found at row 510!
# image found at row 511!
# image found at row 512!
# image found at row 513!
# image found at row 514!
# image found at row 515!
# image found at row 516!
# image found at row 517!
# image found at row 518!
# image found at row 519!
# image found at row 520!
# 521
# image found at row 522!
# image found at row 523!
# image found at row 524!
# image found at row 525!
# image found at row 526!
# image found at row 527!
# image found at row 528!
# image found at row 529!
# image found at row 530!
# 531
# image found at row 532!
# image found at row 533!
# image found at row 534!
# image found at row 535!
# image found at row 536!
# image found at row 537!
# image found at row 538!
# image found at row 539!
# image found at row 540!
# image found at row 541!
# image found at row 542!
# image found at row 543!
# image found at row 544!
# image found at row 545!
# image found at row 546!
# image found at row 547!
# image found at row 548!
# image found at row 549!
# image found at row 550!
# image found at row 551!
# image found at row 552!
# 553
# 554
# 555
# 556
# 557
# image found at row 558!
# 559
# 560
# 561
# 562
# 563
# 564
# 565
# 566
# 567
# 568
# 569
# 570
# 571
# 572
# 573
# image found at row 574!
# image found at row 575!
# 576
# image found at row 577!
# image found at row 578!
# image found at row 579!
# image found at row 580!
# image found at row 581!
# image found at row 582!
# image found at row 583!
# image found at row 584!
# 585
# 586
# 587
# 588
# 589
# image found at row 590!
# image found at row 591!
# image found at row 592!
# image found at row 593!
# image found at row 594!
# image found at row 595!
# image found at row 596!
# image found at row 597!
# image found at row 598!
# image found at row 599!
# image found at row 600!
# 601
# 602
# 603
# image found at row 604!
# image found at row 605!
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# image found at row 613!
# image found at row 614!
# 615
# 616
# 617
# 618
# 619
# 620
# image found at row 621!
# image found at row 622!
# image found at row 623!
# 624
# image found at row 625!
# image found at row 626!
# 627
# image found at row 628!
# image found at row 629!
# image found at row 630!
# image found at row 631!
# image found at row 632!
# image found at row 633!
# image found at row 634!
# image found at row 635!
# image found at row 636!
# image found at row 637!
# image found at row 638!
# image found at row 639!
# image found at row 640!
# image found at row 641!
# image found at row 642!
# image found at row 643!
# image found at row 644!
# image found at row 645!
# image found at row 646!
# image found at row 647!
# image found at row 648!
# image found at row 649!
# image found at row 650!
# image found at row 651!
# image found at row 652!
# image found at row 653!
# image found at row 654!
# 655
# 656
# image found at row 657!
# image found at row 658!
# image found at row 659!
# image found at row 660!
# image found at row 661!
# image found at row 662!
# image found at row 663!
# image found at row 664!
# image found at row 665!
# image found at row 666!
# image found at row 667!
# image found at row 668!
# image found at row 669!
# image found at row 670!
# image found at row 671!
# image found at row 672!
# image found at row 673!
# image found at row 674!
# image found at row 675!
# image found at row 676!
# image found at row 677!
# image found at row 678!
# image found at row 679!
# image found at row 680!
# image found at row 681!
# image found at row 682!
# image found at row 683!
# image found at row 684!
# image found at row 685!
# image found at row 686!
# image found at row 687!
# image found at row 688!
# image found at row 689!
# image found at row 690!
# image found at row 691!
# image found at row 692!
# image found at row 693!
# image found at row 694!
# image found at row 695!
# image found at row 696!
# image found at row 697!
# image found at row 698!
# image found at row 699!
# image found at row 700!
# image found at row 701!
# image found at row 702!
# image found at row 703!
# image found at row 704!
# image found at row 705!
# image found at row 706!
# image found at row 707!
# image found at row 708!
# image found at row 709!
# image found at row 710!
# image found at row 711!
# image found at row 712!
# image found at row 713!
# image found at row 714!
# image found at row 715!
# image found at row 716!
# image found at row 717!
# image found at row 718!
# image found at row 719!
# image found at row 720!
# image found at row 721!
# image found at row 722!
# image found at row 723!
# image found at row 724!
# image found at row 725!
# 726
# 727
# 728
# image found at row 729!
# 730
# image found at row 731!
# image found at row 732!
# image found at row 733!
# image found at row 734!
# image found at row 735!
# image found at row 736!
# image found at row 737!
# image found at row 738!
# image found at row 739!
# image found at row 740!
# image found at row 741!
# image found at row 742!
# image found at row 743!
# image found at row 744!
# image found at row 745!
# image found at row 746!
# image found at row 747!
# image found at row 748!
# image found at row 749!
# image found at row 750!
# image found at row 751!
# image found at row 752!
# image found at row 753!
# image found at row 754!
# image found at row 755!
# image found at row 756!
# image found at row 757!
# image found at row 758!
# image found at row 759!
# image found at row 760!
# image found at row 761!
# image found at row 762!
# image found at row 763!
# image found at row 764!
# image found at row 765!
# image found at row 766!
# image found at row 767!
# image found at row 768!
# image found at row 769!
# image found at row 770!
# image found at row 771!
# image found at row 772!
# image found at row 773!
# image found at row 774!
# image found at row 775!
# image found at row 776!
# image found at row 777!
# image found at row 778!
# image found at row 779!
# image found at row 780!
# image found at row 781!
# image found at row 782!
# image found at row 783!
# image found at row 784!
# image found at row 785!
# image found at row 786!
# image found at row 787!
# image found at row 788!
# image found at row 789!
# image found at row 790!
# image found at row 791!
# image found at row 792!
# image found at row 793!
# image found at row 794!
# image found at row 795!
# image found at row 796!
# image found at row 797!
# image found at row 798!
# image found at row 799!
# image found at row 800!
# image found at row 801!
# image found at row 802!
# image found at row 803!
# image found at row 804!
# image found at row 805!
# image found at row 806!
# image found at row 807!
# image found at row 808!
# image found at row 809!
# image found at row 810!
# image found at row 811!
# image found at row 812!
# image found at row 813!
# image found at row 814!
# image found at row 815!
# image found at row 816!
# image found at row 817!
# image found at row 818!
# image found at row 819!
# image found at row 820!
# image found at row 821!
# image found at row 822!
# image found at row 823!
# image found at row 824!
# image found at row 825!
# image found at row 826!
# image found at row 827!
# image found at row 828!
# image found at row 829!
# image found at row 830!
# image found at row 831!
# 832
# image found at row 833!
# image found at row 834!
# image found at row 835!
# image found at row 836!
# image found at row 837!
# 838
# image found at row 839!
# image found at row 840!
# image found at row 841!
# image found at row 842!
# image found at row 843!
# image found at row 844!
# image found at row 845!
# image found at row 846!
# image found at row 847!
# image found at row 848!
# image found at row 849!
# image found at row 850!
# image found at row 851!
# image found at row 852!
# image found at row 853!
# image found at row 854!
# image found at row 855!
# image found at row 856!
# image found at row 857!
# image found at row 858!
# image found at row 859!
# image found at row 860!
# image found at row 861!
# image found at row 862!
# image found at row 863!
# image found at row 864!
# image found at row 865!
# image found at row 866!
# image found at row 867!
# image found at row 868!
# image found at row 869!
# image found at row 870!
# image found at row 871!
# image found at row 872!
# image found at row 873!
# image found at row 874!
# image found at row 875!
# image found at row 876!
# image found at row 877!
# image found at row 878!
# image found at row 879!
# image found at row 880!
# image found at row 881!
# image found at row 882!
# image found at row 883!
# image found at row 884!
# image found at row 885!
# image found at row 886!
# image found at row 887!
# image found at row 888!
# image found at row 889!
# image found at row 890!
# image found at row 891!
# image found at row 892!
# image found at row 893!
# image found at row 894!
# image found at row 895!
# image found at row 896!
# image found at row 897!
# image found at row 898!
# 899
# image found at row 900!
# image found at row 901!
# image found at row 902!
# image found at row 903!
# image found at row 904!
# 905
# 906
# image found at row 907!
# image found at row 908!
# image found at row 909!
# image found at row 910!
# image found at row 911!
# image found at row 912!
# image found at row 913!
# image found at row 914!
# image found at row 915!
# image found at row 916!
# image found at row 917!
# image found at row 918!
# image found at row 919!
# image found at row 920!
# image found at row 921!
# image found at row 922!
# image found at row 923!
# image found at row 924!
# image found at row 925!
# image found at row 926!
# image found at row 927!
# image found at row 928!
# image found at row 929!
# image found at row 930!
# image found at row 931!
# image found at row 932!
# image found at row 933!
# image found at row 934!
# image found at row 935!
# image found at row 936!
# image found at row 937!
# image found at row 938!
# image found at row 939!
# image found at row 940!
# image found at row 941!
# image found at row 942!
# image found at row 943!
# image found at row 944!
# image found at row 945!
# image found at row 946!
# image found at row 947!
# image found at row 948!
# image found at row 949!
# image found at row 950!
# image found at row 951!
# image found at row 952!
# image found at row 953!
# image found at row 954!
# image found at row 955!
# image found at row 956!
# image found at row 957!
# image found at row 958!
# image found at row 959!
# image found at row 960!
# image found at row 961!
# image found at row 962!
# image found at row 963!
# image found at row 964!
# image found at row 965!
# image found at row 966!
# image found at row 967!
# image found at row 968!
# image found at row 969!
# image found at row 970!
# image found at row 971!
# image found at row 972!
# image found at row 973!
# image found at row 974!
# image found at row 975!
# image found at row 976!
# image found at row 977!
# image found at row 978!
# image found at row 979!
# image found at row 980!
# image found at row 981!
# image found at row 982!
# image found at row 983!
# image found at row 984!
# image found at row 985!
# image found at row 986!
# image found at row 987!
# image found at row 988!
# image found at row 989!
# image found at row 990!
# image found at row 991!
# image found at row 992!
# image found at row 993!
# image found at row 994!
# image found at row 995!
# image found at row 996!
# image found at row 997!
# image found at row 998!
# image found at row 999!
# image found at row 1000!
# image found at row 1001!
# image found at row 1002!
# image found at row 1003!
# image found at row 1004!
# image found at row 1005!
# image found at row 1006!
# image found at row 1007!
# image found at row 1008!
# image found at row 1009!
# image found at row 1010!
# image found at row 1011!
# image found at row 1012!
# image found at row 1013!
# image found at row 1014!
# image found at row 1015!
# image found at row 1016!
# image found at row 1017!
# image found at row 1018!
# image found at row 1019!
# image found at row 1020!
# image found at row 1021!
# image found at row 1022!
# image found at row 1023!
# image found at row 1024!
# image found at row 1025!
# image found at row 1026!
# image found at row 1027!
# image found at row 1028!
# image found at row 1029!
# image found at row 1030!
# image found at row 1031!
# image found at row 1032!
# image found at row 1033!
# image found at row 1034!
# image found at row 1035!
# image found at row 1036!
# image found at row 1037!
# image found at row 1038!
# image found at row 1039!
# image found at row 1040!
# image found at row 1041!
# image found at row 1042!
# image found at row 1043!
# image found at row 1044!
# image found at row 1045!
# image found at row 1046!
# image found at row 1047!
# image found at row 1048!
# image found at row 1049!
# image found at row 1050!
# image found at row 1051!
# image found at row 1052!
# image found at row 1053!
# 1054
# image found at row 1055!
# image found at row 1056!
# image found at row 1057!
# image found at row 1058!
# image found at row 1059!
# image found at row 1060!
# image found at row 1061!
# image found at row 1062!
# image found at row 1063!
# image found at row 1064!
# image found at row 1065!
# 1066
# 1067
# image found at row 1068!
# 1069
# image found at row 1070!
# image found at row 1071!
# image found at row 1072!
# 1073
# image found at row 1074!
# image found at row 1075!
# image found at row 1076!
# image found at row 1077!
# image found at row 1078!
# image found at row 1079!
# image found at row 1080!
# image found at row 1081!
# image found at row 1082!
# image found at row 1083!
# image found at row 1084!
# image found at row 1085!
# image found at row 1086!
# image found at row 1087!
# image found at row 1088!
# image found at row 1089!
# image found at row 1090!
# image found at row 1091!
# image found at row 1092!
# image found at row 1093!
# image found at row 1094!
# image found at row 1095!
# image found at row 1096!
# image found at row 1097!
# image found at row 1098!
# image found at row 1099!
# 1100
# image found at row 1101!
# image found at row 1102!
# image found at row 1103!
# 1104
# image found at row 1105!
# 1106
# image found at row 1107!
# image found at row 1108!
# image found at row 1109!
# image found at row 1110!
# image found at row 1111!
# image found at row 1112!
# image found at row 1113!
# image found at row 1114!
# image found at row 1115!
# image found at row 1116!
# image found at row 1117!
# image found at row 1118!
# 1119
# 1120
# image found at row 1121!
# 1122
# 1123
# image found at row 1124!
# image found at row 1125!
# image found at row 1126!
# image found at row 1127!
# image found at row 1128!
# image found at row 1129!
# image found at row 1130!
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# image found at row 1137!
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# image found at row 1157!
# 1158
# image found at row 1159!
# image found at row 1160!
# 1161
# image found at row 1162!
# 1163
# image found at row 1164!
# image found at row 1165!
# image found at row 1166!
# 1167
# 1168
# 1169
# 1170
# image found at row 1171!
# image found at row 1172!
# image found at row 1173!
# image found at row 1174!
# image found at row 1175!
# image found at row 1176!
# image found at row 1177!
# image found at row 1178!
# image found at row 1179!
# image found at row 1180!
# image found at row 1181!
# image found at row 1182!
# image found at row 1183!
# image found at row 1184!
# image found at row 1185!
# image found at row 1186!
# image found at row 1187!
# image found at row 1188!
# image found at row 1189!
# image found at row 1190!
# 1191
# image found at row 1192!
# image found at row 1193!
# image found at row 1194!
# image found at row 1195!
# image found at row 1196!
# image found at row 1197!
# image found at row 1198!
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# image found at row 1215!
# image found at row 1216!
# image found at row 1217!
# image found at row 1218!
# image found at row 1219!
# image found at row 1220!
# image found at row 1221!
# image found at row 1222!
# image found at row 1223!
# image found at row 1224!
# image found at row 1225!
# image found at row 1226!
# image found at row 1227!
# image found at row 1228!
# image found at row 1229!
# image found at row 1230!
# image found at row 1231!
# 1232
# image found at row 1233!
# image found at row 1234!
# image found at row 1235!
# image found at row 1236!
# image found at row 1237!
# image found at row 1238!
# image found at row 1239!
# image found at row 1240!
# image found at row 1241!
# 1242
# image found at row 1243!
# 1244
# image found at row 1245!
# 1246
# image found at row 1247!
# image found at row 1248!
# image found at row 1249!
# image found at row 1250!
# image found at row 1251!
# image found at row 1252!
# image found at row 1253!
# image found at row 1254!
# 1255
# 1256
# image found at row 1257!
# image found at row 1258!
# 1259
# 1260
# 1261
# 1262
# image found at row 1263!
# 1264
# 1265
# image found at row 1266!
# image found at row 1267!
# image found at row 1268!
# image found at row 1269!
# image found at row 1270!
# image found at row 1271!
# image found at row 1272!
# image found at row 1273!
# image found at row 1274!
# image found at row 1275!
# image found at row 1276!
# image found at row 1277!
# image found at row 1278!
# 1279
# image found at row 1280!
# image found at row 1281!
# image found at row 1282!
# image found at row 1283!
# image found at row 1284!
# image found at row 1285!
# image found at row 1286!
# image found at row 1287!
# image found at row 1288!
# image found at row 1289!
# image found at row 1290!
# image found at row 1291!
# image found at row 1292!
# image found at row 1293!
# image found at row 1294!
# image found at row 1295!
# image found at row 1296!
# image found at row 1297!
# image found at row 1298!
# image found at row 1299!
# image found at row 1300!
# image found at row 1301!
# image found at row 1302!
# image found at row 1303!
# image found at row 1304!
# image found at row 1305!
# image found at row 1306!
# image found at row 1307!
# image found at row 1308!
# image found at row 1309!
# image found at row 1310!
# 1311
# image found at row 1312!
# image found at row 1313!
# image found at row 1314!
# image found at row 1315!
# image found at row 1316!
# image found at row 1317!
# image found at row 1318!
# image found at row 1319!
# image found at row 1320!
# image found at row 1321!
# image found at row 1322!
# image found at row 1323!
# image found at row 1324!
# image found at row 1325!
# image found at row 1326!
# image found at row 1327!
# image found at row 1328!
# image found at row 1329!
# image found at row 1330!
# image found at row 1331!
# image found at row 1332!
# image found at row 1333!
# image found at row 1334!
# image found at row 1335!
# image found at row 1336!
# image found at row 1337!
# image found at row 1338!
# image found at row 1339!
# image found at row 1340!
# image found at row 1341!
# image found at row 1342!
# 1343
# image found at row 1344!
# 1345
# image found at row 1346!
# image found at row 1347!
# image found at row 1348!
# image found at row 1349!
# image found at row 1350!
# image found at row 1351!
# image found at row 1352!
# image found at row 1353!
# image found at row 1354!
# image found at row 1355!
# image found at row 1356!
# image found at row 1357!
# image found at row 1358!
# image found at row 1359!
# 1360
# image found at row 1361!
# image found at row 1362!
# image found at row 1363!
# image found at row 1364!
# image found at row 1365!
# image found at row 1366!
# image found at row 1367!
# image found at row 1368!
# image found at row 1369!
# image found at row 1370!
# image found at row 1371!

# %%
df_images = df[df['has_image'] == True]

# %%
#Saving fixed values to document 
writer = pd.ExcelWriter('blanton_test.xlsx', engine='xlsxwriter', 
                        options = {'string_to_numbers' : False})
df_images.to_excel(writer)

writer.save()

# %%
# compare sizes of old and new dataframe
df_rows = len(df.axes[0])
df_images_rows = len(df_images.axes[0])
diff = (df_images_rows / df_rows) * 100

print(str(diff) + "% of rows have images")
# Out:
# 78.4256559766764% of rows have images

# %%
#Number of images
print(str(len(df_images)))
# Out:
# 1076

# %%
#Create databased of random images to judge
rand_fron = df_images.sample(n=60)
rand_ana = df_images.sample(n=60)

rand_fron['student_id'] = 'Frp323'
rand_ana['student_id'] = 'AnaW4804'

rand_fron['Emotional_Reaction'] = 0
rand_ana['Emotional_Reaction'] = 0

rand_fron['Asthetically_Pleasing'] = 0
rand_ana['Asthetically_Pleasing'] = 0

rand_fron.head()
# Out:
#         Accession #       Artist sort name  \
# 1096  P1967.1.18/20          Atget, Eugene
# 449         2017.11         Bruscky, Paulo
# 748   1992.253.6/35        Camnitzer, Luis
# 1364         2005.2          Jiménez, Luis
# 1233  1995.178.8/27  Lepère, Auguste Louis
#
#                                      Artist life dates Artist Nationality  \
# 1096    (Libourne, France, 1857 - 1927, Paris, France)             French
# 449                          (Recife, Brazil, 1949 – )          Brazilian
# 748                         (Lübeck, Germany, 1937 - )            Uruguay
# 1364  (El Paso, Texas, 1940 - 2006, Hondo, New Mexico)           American
# 1233       (Paris, France, 1849 - 1918, Domme, France)             French
#
#                                                   Title  \
# 1096  Faucheurs, Somme [Reapers, Somme], from Twenty...
# 449                               Sem título [Untitled]
# 748   The weight drove his pulse into the wall, plat...
# 1364                                    Border Crossing
# 1233  Le Marché à la Ferraille, Paris, from L'Oeuvre...
#
#                   Creation date                                   Medium  \
# 1096  before 1900, printed 1956                     Gelatin silver print
# 449                        n.d.                                Photocopy
# 748                        1983  Four-color photo etching on chine collé
# 1364                       1987                       Painted fiberglass
# 1233                        NaN                           Wood engraving
#
#                                             Credit Line  \
# 1096  Blanton Museum of Art, The University of Texas...
# 449   Blanton Museum of Art, The University of Texas...
# 748   Blanton Museum of Art, The University of Texas...
# 1364  Blanton Museum of Art, The University of Texas...
# 1233  Blanton Museum of Art, The University of Texas...
#
#                                              Dimensions Unnamed: 9       \
# 1096          15.8 cm x 21.3 cm (6 1/4 in. x 8 3/8 in.)        yes  NaN
# 449                    20 x 20.7 cm (7 7/8 x 8 1/8 in.)        yes  NaN
# 748        74.7 cm x 56.2 cm (29 7/16 in. x 22 1/8 in.)        yes  NaN
# 1364  82.5 cm x 29.2 cm x 24.1 cm (32 1/2 in. x 11 1...         no  NaN
# 1233      25.2 cm x 29.3 cm (9 15/16 in. x 11 9/16 in.)        yes  NaN
#
#      has_image student_id  Emotional_Reaction  Asthetically_Pleasing
# 1096      True     Frp323                   0                      0
# 449       True     Frp323                   0                      0
# 748       True     Frp323                   0                      0
# 1364      True     Frp323                   0                      0
# 1233      True     Frp323                   0                      0

# %%
rand_ana.head()
# Out:
#               Accession #    Artist sort name  \
# 665   2003.154.1/19-19/19    Sugarman, George
# 1128          1993.4.1/16     Callot, Jacques
# 140               1982.99      Leal, Fernando
# 94                1977.11  Polesello, Rogelio
# 763        1992.253.22/35     Camnitzer, Luis
#
#                                       Artist life dates Artist Nationality  \
# 665   (New York, New York, 1912 - 1999, New York, Ne...           American
# 1128        (Nancy, France, 1592 - 1635, Nancy, France)             French
# 140                                       (1900 - 1964)            Mexican
# 94    (Buenos Aires, Argentina, 1939 - 2014, Buenos ...        Argentinean
# 763                          (Lübeck, Germany, 1937 - )            Uruguay
#
#                                                   Title Creation date  \
# 665                                          Two in One          1966
# 1128  Mort de Judas [Death of Judas], from Les Petit...          1632
# 140                                 Danzantes [Dancers]          1922
# 94                                             Untitled          1968
# 763   After the shadow passed, he would feed them, p...          1983
#
#                                                  Medium  \
# 665   Polychromed wood installation of nineteen elem...
# 1128                                            Etching
# 140                                             Woodcut
# 94                                     Tempera on paper
# 763             Four-color photo etching on chine collé
#
#                                             Credit Line  \
# 665   Blanton Museum of Art, The University of Texas...
# 1128  Blanton Museum of Art, The University of Texas...
# 140   Blanton Museum of Art, The University of Texas...
# 94    Blanton Museum of Art, The University of Texas...
# 763   Blanton Museum of Art, The University of Texas...
#
#                                              Dimensions Unnamed: 9       \
# 665   247.6 cm x 726.4 cm x 340.4 cm (97 1/2 in. x 2...         no  NaN
# 1128        7.1 cm x 4.3 cm (2 13/16 in. x 1 11/16 in.)        yes  NaN
# 140           31.4 cm x 24 cm (12 3/8 in. x 9 7/16 in.)        yes  NaN
# 94               58.4 cm x 37 cm (23 in. x 14 9/16 in.)        yes  NaN
# 763             74.9 cm x 55.9 cm (29 1/2 in. x 22 in.)        yes  NaN
#
#      has_image student_id  Emotional_Reaction  Asthetically_Pleasing
# 665       True   AnaW4804                   0                      0
# 1128      True   AnaW4804                   0                      0
# 140       True   AnaW4804                   0                      0
# 94        True   AnaW4804                   0                      0
# 763       True   AnaW4804                   0                      0

# %%
#Saving Fron Random
writer = pd.ExcelWriter('student_Frp323_blanton.xlsx', engine='xlsxwriter', 
                        options = {'string_to_numbers' : False})
rand_fron.to_excel(writer)

writer.save()

# %%
#Saving Ana Random
writer = pd.ExcelWriter('student_AnaW4804_blanton.xlsx', engine='xlsxwriter', 
                        options = {'string_to_numbers' : False})
rand_ana.to_excel(writer)

writer.save()
